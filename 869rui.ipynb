# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np  
import os

# !pip install seaborn
import seaborn as sns

from pandas.api.types import CategoricalDtype
Train_label = pd.read_csv('Training set labels.csv')
Train_value = pd.read_csv('Training set values.csv')
Test_value = pd.read_csv('Test set values.csv')
Train = pd.merge(Train_value,Train_label, how='inner',left_on='id',right_on='id', left_index=False)
# Out:
# ...
#   Using cached pandas-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (10.8 MB)
# ...
#   Using cached numpy-1.21.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# ...
#   Using cached seaborn-0.11.1-py3-none-any.whl (285 kB)
# ...
#   Using cached matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
# ...
#   Using cached scipy-1.7.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached Pillow-8.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# ...
#   Using cached kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# ...

# %%
Train.shape
# Out:
# (59400, 41)

# %%
Train.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... water_quality  \
# 0  34.938093  -9.856322                  none            0  ...          soft
# 1  34.698766  -2.147466              Zahanati            0  ...          soft
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...          soft
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...          soft
# 4  31.130847  -1.825359               Shuleni            0  ...          soft
#
# ...

# %%
Train.isnull().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# ...

# %%
permit = Train[['permit','status_group']].fillna("UNKNOWN")

# %%
permit.pivot_table(index = 'permit', columns= 'status_group', aggfunc=len)
# Out:
# status_group  functional  functional needs repair  non functional
# permit
# False               9045                     1320            7127
# True               21541                     2697           14614
# UNKNOWN             1673                      300            1083

# %%
type = Train[['extraction_type_class','status_group']]

# %%
type.pivot_table(index = 'extraction_type_class', columns= 'status_group', aggfunc=len)
# Out:
# status_group           functional  functional needs repair  non functional
# extraction_type_class
# gravity                     16048                     2701            8031
# handpump                    10375                      995            5086
# motorpump                    1135                      138            1714
# other                        1029                      206            5195
# rope pump                     293                       17             141
# submersible                  3329                      253            2597
# wind-powered                   50                        7              60

# %%
mgmt = Train[['management_group','status_group']]

# %%
mgmt.pivot_table(index = 'management_group', columns= 'status_group', aggfunc=len)
# Out:
# status_group      functional  functional needs repair  non functional
# management_group
# commercial              2235                      117            1286
# other                    528                       56             359
# parastatal              1020                      211             537
# unknown                  224                       27             310
# user-group             28252                     3906           20332

# %%
pay = Train[['payment_type','status_group']]

# %%
pay.pivot_table(index = 'payment_type', columns= 'status_group', aggfunc=len)
# Out:
# status_group  functional  functional needs repair  non functional
# payment_type
# annually            2740                      247             655
# monthly             5482                      927            1891
# never pay          11379                     1907           12062
# on failure          2429                      277            1208
# other                611                      118             325
# per bucket          6090                      409            2486
# unknown             3528                      432            4197

# %%
quality = Train[['quality_group','status_group']]

# %%
quality.pivot_table(index = 'quality_group', columns= 'status_group', aggfunc=len)
# Out:
# status_group   functional  functional needs repair  non functional
# quality_group
# colored               246                       54             190
# fluoride              157                       13              47
# good                28760                     3904           18154
# milky                 438                       14             352
# salty                2394                      297            2504
# unknown               264                       35            1577

# %%
quantity = Train[['quantity_group','status_group']]

# %%
quantity.pivot_table(index = 'quantity_group', columns= 'status_group', aggfunc=len)
# Out:
# status_group    functional  functional needs repair  non functional
# quantity_group
# dry                    157                       37            6052
# enough               21648                     2400            9138
# insufficient          7916                     1450            5763
# seasonal              2325                      416            1309
# unknown                213                       14             562
